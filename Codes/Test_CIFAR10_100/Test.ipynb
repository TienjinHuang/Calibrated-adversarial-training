# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# %cd /content/drive/My\ Drive/Projects/ICML2021_final/Codes/Test_CIFAR10_100
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Projects/ICML2021_final/Codes/Test_CIFAR10_100

# %%
# !ls 
# !nvidia-smi
# Out:
# attack_generator.py  data	  models       Test.ipynb
# attack_test.py	     __init__.py  __pycache__  wideresnet_trades.py
# Wed Feb 10 13:03:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# ...

# %% [markdown]
# #Test for cifar10

# %%
# !python attack_test.py --net 'resnet18' --model_path '../Trained_models/CIFAR10/RN18_b_5_b1_005_e8_cw.pth' --preprocess 'meanstd' --dataset 'cifar10'
# Out:
# ==> Load Test Data
# Files already downloaded and verified
# ==> Load Model
# resnet18
# ==> Evaluating Performance under White-box Adversarial Attack
# Natural Test Accuracy: 84.22%
# FGSM without Random Start Test Accuracy: 59.07%
# PGD20 without Random Start Test Accuracy: 55.29%
# PGD100 without Random Start Test Accuracy: 54.33%
# CW with Random Start Test Accuracy: 51.61%

# %% [markdown]
# #Test for CIFAR100

# %%
# !python attack_test.py --net 'resnet18' --model_path '../Trained_models/CIFAR100/RN18_b_5_b1_005_e8_cw.pth' --preprocess 'meanstd' --dataset 'cifar100'
# Out:
# ==> Load Test Data
# ...
# 169009152it [00:02, 73770382.62it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# ==> Load Model
# resnet18
# ==> Evaluating Performance under White-box Adversarial Attack
# Natural Test Accuracy: 58.90%
# FGSM without Random Start Test Accuracy: 31.51%
# PGD20 without Random Start Test Accuracy: 29.11%
# PGD100 without Random Start Test Accuracy: 28.50%
# CW with Random Start Test Accuracy: 26.33%
