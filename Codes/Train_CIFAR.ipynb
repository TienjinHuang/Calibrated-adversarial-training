# %%
# %cd /content/drive/MyDrive/Projects/AT/
# Out:
# /content/drive/MyDrive/Projects/AT

# %%
# !ls
# !nvidia-smi
# Out:
# cifar_model_b1_b01_e8_noise01_resNet
# cifar_model_b1_b01_e8_noise01_resNet_repeat
# cifar_model_b1_b05_e8_noise01_resNet
# cifar_model_b1_b05_e8_noise01_resNet_cw
# cifar_model_b2_b05_e8_noise01_resNet
# cifar_model_b3_b05_e8_noise01_resNet
# cifar_model_b4_b05_e8_noise01_resNet
# cifar_model_b5_b001_e8_noise01_resNet
# cifar_model_b5_b001_e8_noise01_resNet_cw
# cifar_model_b5_b005_e8_noise01_repeat1
# cifar_model_b5_b005_e8_noise01_Resnet_CELOSS
# cifar_model_b5_b005_e8_noise01_Resnet_CELOSS_only
# cifar_model_b5_b005_e8_noise01_resNet_cw
# cifar_model_b5_b01_e8_noise01_resNet_cw
# cifar_model_b5_b01_e8_noise01_resNet_cw_cifar_100_repeat1
# cifar_model_b5_b01_e8_noise01_resNet_cw_cifar_100_repeat2
# cifar_model_b5_b01_e8_noise01_ResNet_repeat1
# cifar_model_b5_b01_e8_noise01_ResNet_repeat2
# cifar_model_b5_b03_e8_noise01_resNet
# cifar_model_b5_b05_e11_noise01_ResNet_repeat1
# cifar_model_b5_b05_e11_noise01_ResNet_repeat2
# cifar_model_b5_b05_e12_noise01_ResNet_repeat1
# ...

# %% [markdown]
# #Train for CIFAR100- an example

# %%
! python Train_CIFAR100.py --attackloss 'cw' --epsilon 8 --b 5 --b1 0.05

# %% [markdown]
# #Training CIFAR10-an example

# %%
! python Train_CIFAR10.py --attackloss 'cw' --epsilon 8 --b 5 --b1 0.1
